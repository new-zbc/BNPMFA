# %%
import os
import torch
import pandas as pd
import scanpy as sc
from sklearn import metrics
import multiprocessing as mp
import numpy as np
from GraphST import GraphST
from GraphST.utils import clustering
device = 'cuda:1' if torch.cuda.is_available() else 'cpu'

folder_list = [ "nb"]

# %%
def mclust_P(adata, num_cluster, modelNames='EEE', used_obsm='STAGATE', random_seed=2020):
    """\
    Clustering using the mclust algorithm.
    The parameters are the same as those in the R package mclust.
    """
    
    np.random.seed(random_seed)
    from sklearn.mixture import GaussianMixture
    

    gmm = GaussianMixture(n_components=num_cluster, random_state=random_seed).fit(adata.obsm[used_obsm])
    mclust_res = gmm.predict(adata.obsm[used_obsm])

    adata.obs['mclust'] = mclust_res
    adata.obs['mclust'] = adata.obs['mclust'].astype('int')
    adata.obs['mclust'] = adata.obs['mclust'].astype('category')
    return adata

# %%
#folder = "scenario1_7"

for folder in folder_list:
    if not os.path.exists(folder + "/" + "GraphST"):
        os.makedirs(folder + "/" + "GraphST")



    result = pd.DataFrame(columns = ["ARI", "AMI", "NMI"])

    for data_index in range(30):
        data = str(data_index + 1)
        file_name = folder + "/"+ "SpaGCN/data/" + data +".h5ad"
        adata = sc.read_h5ad(file_name)
        adata.X = adata.X.astype("float32")
        adata.obsm["spatial"] = pd.concat([adata.obs["row"], adata.obs["col"]], axis=1)
        adata.var["highly_variable"] = True


        model = GraphST.GraphST(adata, device=device)
        adata = model.train()
        # set radius to specify the number of neighbors considered during refinement
        radius = 1.42

        tool = 'mclust' # mclust, leiden, and louvain
        n_clusters = np.unique(adata.obs["label"]).size

        # clustering
        if tool == 'mclust':
            adata = mclust_P(adata, used_obsm='emb', num_cluster=np.unique(adata.obs["label"]).size) # For DLPFC dataset, we use optional refinement step.
        elif tool in ['leiden', 'louvain']:
            clustering(adata, n_clusters, radius=radius, method=tool, start=0.1, end=1.0, increment=0.01, refinement=False)

        from sklearn import metrics
        adata.obs["pred"] = adata.obs["mclust"]
        obs_df = adata.obs.dropna()
        ari = metrics.adjusted_rand_score(obs_df['pred'], obs_df['label'])
        nmi = metrics.normalized_mutual_info_score(obs_df['pred'], obs_df['label'])
        ami = metrics.adjusted_mutual_info_score(obs_df['pred'], obs_df['label'])

        values= [ari, ami, nmi]
        result.loc[data_index] = values

        obs_df["pred"].to_csv(folder + "/GraphST/" + data + ".csv")

    result_file = folder + "/summary/" + "GraphST.csv"
    result.to_csv(result_file )
# Out:
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 145.02it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 145.57it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 141.23it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.89it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 138.32it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 145.37it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 142.47it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.41it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 140.32it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.63it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 140.52it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.42it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.79it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.54it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.01it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.08it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.52it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 137.53it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.92it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 138.65it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 144.24it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 132.68it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 128.73it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 129.42it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 128.56it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 129.23it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 131.41it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 141.37it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 130.69it/s]
# Optimization finished for ST data!
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 140.62it/s]
# Optimization finished for ST data!

# %%
# !pip3 install leidenalg
# Out:
# Collecting leidenalg
#   Downloading leidenalg-0.11.0-cp38-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 29.4 MB/s eta 0:00:0000:0100:01
#   Downloading leidenalg-0.10.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 35.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: igraph<0.12,>=0.10.0 in /home/project07/.conda/envs/GraphST/lib/python3.8/site-packages (from leidenalg) (0.11.8)
# Requirement already satisfied: texttable>=1.6.2 in /home/project07/.conda/envs/GraphST/lib/python3.8/site-packages (from igraph<0.12,>=0.10.0->leidenalg) (1.7.0)
# Installing collected packages: leidenalg
# Successfully installed leidenalg-0.10.2

# %%
folder = "scenario3_2"
result = pd.DataFrame(columns = ["ARI", "AMI", "NMI"])
data_index  = 0
data = str(data_index + 1)
file_name = folder + "/"+ "SpaGCN/data/" + data +".h5ad"
adata = sc.read_h5ad(file_name)
adata.X = adata.X.astype("float32")
adata.obsm["spatial"] = pd.concat([adata.obs["row"], adata.obs["col"]], axis=1)
adata.obs["Ground Truth"] = adata.obs["label"]
adata.var["highly_variable"] = True

# %%
adata.var["highly_variable"]
# Out:
# gene-1       True
# gene-2       True
# gene-3       True
# gene-4       True
# gene-5       True
#              ...
# gene-1996    True
# gene-1997    True
# gene-1998    True
# gene-1999    True
# gene-2000    True
# Name: highly_variable, Length: 2000, dtype: bool

# %%
# define model
model = GraphST.GraphST(adata, device=device)
adata = model.train()
# Out:
# Begin to train ST data...
# 100%|██████████| 600/600 [00:04<00:00, 139.55it/s]
# Optimization finished for ST data!

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1600 × 2000
#     obs: 'orig.ident', 'nCount_originalexp', 'nFeature_originalexp', 'row', 'col', 'label', 'Ground Truth'
#     var: 'features', 'highly_variable'
#     obsm: 'X_PCA', 'spatial'

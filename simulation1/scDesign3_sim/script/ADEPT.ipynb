# %%
import pandas as pd
import numpy as np
import scanpy as sc
import torch
import os
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
from GAAE import GAAE, Train_ADEPT_modified, utils

folder_list = ["nb"]
# Out:
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
for folder in folder_list:
    if not os.path.exists(folder + "/" + "ADEPT"):
        os.makedirs(folder + "/" + "ADEPT")

    result = pd.DataFrame(columns = ["ARI", "AMI", "NMI"])

    for data_index in range(30):
        data = str(data_index + 1)
        file_name = folder + "/"+ "SpaGCN/data/" + data +".h5ad"
        adata = sc.read_h5ad(file_name)
        adata.X = adata.X.astype("float32")
        adata.obsm["spatial"] = pd.concat([adata.obs["row"], adata.obs["col"]], axis=1)
        adata.obs["Ground Truth"] = adata.obs["label"]
        utils.get_kNN(adata, rad_cutoff=1.42)
        ari_ini, ARI, de_list, adata_out = Train_ADEPT_modified.train_ADEPT_use_DE(adata, n_epochs=1000, num_cluster=np.unique(adata.obs["label"]).size, device_id="0")

        from sklearn import metrics
        adata.obs["pred"] = adata_out.obs['mclust_impute']
        obs_df = adata.obs.dropna()
        ari = metrics.adjusted_rand_score(obs_df['pred'], obs_df['label'])
        nmi = metrics.normalized_mutual_info_score(obs_df['pred'], obs_df['label'])
        ami = metrics.adjusted_mutual_info_score(obs_df['pred'], obs_df['label'])

        values= [ari, ami, nmi]
        result.loc[data_index] = values

        obs_df["pred"].to_csv(folder + "/ADEPT/" + data + ".csv")

    result_file = folder + "/summary/" + "ADEPT.csv"
    result.to_csv(result_file )
# Out:
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 282.23it/s]
# ARI =  0.2992686602936739
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  676
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6927829876316408
# 100%|██████████| 1000/1000 [00:03<00:00, 290.82it/s]
# finalized ARI =  0.3632021435753972
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 288.49it/s]
# ARI =  0.3061984230036031
# selecting DEs after first round of clustering ...
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  638
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6934689858877584
# 100%|██████████| 1000/1000 [00:03<00:00, 300.02it/s]
# finalized ARI =  0.36993517323795627
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 279.01it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.2859585336167962
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  660
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6997866754184444
# 100%|██████████| 1000/1000 [00:03<00:00, 289.83it/s]
# finalized ARI =  0.37235447495997004
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 291.16it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.2511198951993944
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  595
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7097897642811637
# 100%|██████████| 1000/1000 [00:03<00:00, 292.19it/s]
# finalized ARI =  0.3135859862074887
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 286.17it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.2944617125062232
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  651
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7000726458045662
# 100%|██████████| 1000/1000 [00:03<00:00, 286.70it/s]
# finalized ARI =  0.30900356545093105
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 278.32it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.2946088818704578
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  633
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7016955532362653
# 100%|██████████| 1000/1000 [00:03<00:00, 294.20it/s]
# finalized ARI =  0.33754885172640814
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 295.05it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.30404822256884023
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  656
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6942249273575768
# 100%|██████████| 1000/1000 [00:03<00:00, 297.46it/s]
# finalized ARI =  0.3275801494674373
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 291.94it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.3572610542121181
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  584
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6998912022155185
# 100%|██████████| 1000/1000 [00:03<00:00, 296.34it/s]
# finalized ARI =  0.3083642572961386
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 292.08it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.2747397227883793
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  647
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7018061701047322
# 100%|██████████| 1000/1000 [00:03<00:00, 293.74it/s]
# finalized ARI =  0.31584151345174805
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 291.25it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.3339244335050078
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  665
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6911810211449201
# 100%|██████████| 1000/1000 [00:03<00:00, 297.13it/s]
# finalized ARI =  0.3531771399928681
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 308.44it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.29795714591278644
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  626
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7186941327089653
# 100%|██████████| 1000/1000 [00:03<00:00, 294.42it/s]
# finalized ARI =  0.2872083093605861
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 292.59it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.28036563419456967
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  638
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6911886196711293
# 100%|██████████| 1000/1000 [00:03<00:00, 295.59it/s]
# finalized ARI =  0.2680159099891598
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 289.84it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.3143536122960112
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  666
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7029032642751054
# 100%|██████████| 1000/1000 [00:03<00:00, 295.14it/s]
# finalized ARI =  0.30769922629247287
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 291.33it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.25807476609954494
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  623
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7139843890340787
# 100%|██████████| 1000/1000 [00:03<00:00, 287.34it/s]
# finalized ARI =  0.3018663568884726
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 293.63it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.33223111075661066
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  652
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7135722353879206
# 100%|██████████| 1000/1000 [00:03<00:00, 296.10it/s]
# finalized ARI =  0.32486996193528817
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 290.09it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.3031406900891831
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  626
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6986597617097842
# 100%|██████████| 1000/1000 [00:03<00:00, 293.35it/s]
# finalized ARI =  0.3113973966031067
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 291.72it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.3561115414613803
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  652
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7061305397444132
# 100%|██████████| 1000/1000 [00:03<00:00, 293.48it/s]
# finalized ARI =  0.32726742422372485
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 290.70it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.22366483373541632
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  619
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7057440963939742
# 100%|██████████| 1000/1000 [00:03<00:00, 294.51it/s]
# finalized ARI =  0.31019961240099847
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 289.80it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.32068609392489866
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  667
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7038953447463994
# 100%|██████████| 1000/1000 [00:03<00:00, 295.25it/s]
# finalized ARI =  0.35798102073698157
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 292.32it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.3094415590278408
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  655
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7026814010527186
# 100%|██████████| 1000/1000 [00:03<00:00, 296.89it/s]
# finalized ARI =  0.2772105809233785
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 294.38it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.31319272766239464
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  671
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7067472977989637
# 100%|██████████| 1000/1000 [00:03<00:00, 294.20it/s]
# finalized ARI =  0.3652363844585074
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 291.91it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.23693592180763706
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  589
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6828804864145924
# 100%|██████████| 1000/1000 [00:03<00:00, 295.72it/s]
# finalized ARI =  0.39235445611613384
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 294.68it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.3001784653173572
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  641
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7047314383550072
# 100%|██████████| 1000/1000 [00:03<00:00, 296.92it/s]
# finalized ARI =  0.30939715164242076
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 293.24it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.3707102385428703
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  675
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6875304185051477
# 100%|██████████| 1000/1000 [00:03<00:00, 295.85it/s]
# finalized ARI =  0.34875857221846046
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 293.43it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.30386031719929046
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  638
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.700179939567466
# 100%|██████████| 1000/1000 [00:03<00:00, 295.57it/s]
# finalized ARI =  0.29827355609915723
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 292.35it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.2754544309076583
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  676
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7051246448636063
# 100%|██████████| 1000/1000 [00:03<00:00, 297.76it/s]
# finalized ARI =  0.31684997549522237
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 291.27it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.36773698004333466
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  659
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6957922242978367
# 100%|██████████| 1000/1000 [00:03<00:00, 299.50it/s]
# finalized ARI =  0.39883408719830427
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 296.44it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.31835174880335204
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  642
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7070526446011449
# 100%|██████████| 1000/1000 [00:03<00:00, 295.31it/s]
# finalized ARI =  0.3309255753288504
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 294.50it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.30425215096058883
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  650
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.7094862538183838
# 100%|██████████| 1000/1000 [00:03<00:00, 296.07it/s]
# finalized ARI =  0.3692349550499504
# ------Calculating spatial graph...
# The graph contains 1976 edges, 277 cells.
# 7.1336 neighbors per cell on average.
# Size of Input:  (277, 1000)
# 100%|██████████| 1000/1000 [00:03<00:00, 293.81it/s]
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.2687707264683045
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/scDesign3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# selecting DE num =  670
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  0.6982111105124198
# 100%|██████████| 1000/1000 [00:03<00:00, 297.96it/s]
# finalized ARI =  0.33048386751900777

# %%
folder = "scenario3_2"
result = pd.DataFrame(columns = ["ARI", "AMI", "NMI"])
data_index  = 0
data = str(data_index + 1)
file_name = folder + "/"+ "SpaGCN/data/" + data +".h5ad"
adata = sc.read_h5ad(file_name)
adata.X = adata.X.astype("float32")
adata.obsm["spatial"] = pd.concat([adata.obs["row"], adata.obs["col"]], axis=1)
adata.obs["Ground Truth"] = adata.obs["label"]

# %%
from GAAE import GAAE, Train_ADEPT_modified, utils

utils.get_kNN(adata, rad_cutoff=1.414)
ari_ini, ARI, de_list, adata_out = Train_ADEPT_modified.train_ADEPT_use_DE(adata, n_epochs=1000, num_cluster=np.unique(adata.obs["label"]).size, device_id="1")
# Out:
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:04<00:00, 241.84it/s]
# ARI =  0.4704436095711588
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  6
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  7
# selecting DE num =  1180
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 292.71it/s]
# finalized ARI =  0.28713878149497046

# %%
adata_out
from sklearn import metrics
metrics.adjusted_rand_score(adata_out.obs['mclust_impute'], adata_out.obs['label'])
# Out:
# 0.28713878149497046

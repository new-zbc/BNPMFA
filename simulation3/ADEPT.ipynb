# %%
import pandas as pd
import numpy as np
import scanpy as sc
import torch
import os
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
from GAAE import GAAE, Train_ADEPT_modified, utils

#folder_list = ["scenario2_1/p_5000", "scenario2_1/p_10000", "scenario2_1/p_15000", "scenario2_1/p_20000", "scenario2_1/p_25000"]
folder_list = ["scenario2_1/p_10000"]
# Out:
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
for folder in folder_list:
    if not os.path.exists(folder + "/" + "ADEPT"):
        os.makedirs(folder + "/" + "ADEPT")

    result = pd.DataFrame(columns = ["ARI", "AMI", "NMI"])

    for data_index in range(30):
        data = str(data_index + 1)
        file_name = folder + "/"+ "SpaGCN/data/" + data +".h5ad"
        adata = sc.read_h5ad(file_name)
        adata.X = adata.X.astype("float32")
        adata.obsm["spatial"] = pd.concat([adata.obs["row"], adata.obs["col"]], axis=1)
        adata.obs["Ground Truth"] = adata.obs["label"]
        utils.get_kNN(adata, rad_cutoff=1.414)
        ari_ini, ARI, de_list, adata_out = Train_ADEPT_modified.train_ADEPT_use_DE(adata, n_epochs=1000, num_cluster=np.unique(adata.obs["label"]).size, device_id="0")

        from sklearn import metrics
        adata.obs["pred"] = adata_out.obs['mclust_impute']
        obs_df = adata.obs.dropna()
        ari = metrics.adjusted_rand_score(obs_df['pred'], obs_df['label'])
        nmi = metrics.normalized_mutual_info_score(obs_df['pred'], obs_df['label'])
        ami = metrics.adjusted_mutual_info_score(obs_df['pred'], obs_df['label'])

        values= [ari, ami, nmi]
        result.loc[data_index] = values

        obs_df["pred"].to_csv(folder + "/ADEPT/" + data + ".csv")

    result_file = folder + "/summary/" + "ADEPT.csv"
    result.to_csv(result_file )
# Out:
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 147.42it/s]
# ARI =  0.4664899796829547
# selecting DEs after first round of clustering ...
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  992
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 289.88it/s]
# finalized ARI =  0.6493531657091133
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 152.95it/s]
# ARI =  0.3886221664999357
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  965
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 298.34it/s]
# finalized ARI =  0.4884058207665781
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 153.03it/s]
# ARI =  0.30798532222215236
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  789
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 298.26it/s]
# finalized ARI =  0.6549439676277122
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 153.42it/s]
# ARI =  0.36111510440118244
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  927
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 299.24it/s]
# finalized ARI =  0.5720037826852499
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 152.73it/s]
# ARI =  0.4497873728318351
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  947
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 293.72it/s]
# finalized ARI =  0.5710115552717868
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 152.99it/s]
# ARI =  0.47491898764188345
# selecting DEs after first round of clustering ...
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  924
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 304.96it/s]
# finalized ARI =  0.571382080966528
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00,
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.99it/s]
# ARI =  0.29952346252785583
# selecting DEs after first round of clustering ...
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  941
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 308.83it/s]
# finalized ARI =  0.34860360474629665
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.98it/s]
# ARI =  0.3485806577078867
# selecting DEs after first round of clustering ...
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  952
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 310.12it/s]
# finalized ARI =  0.5962001786199266
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.99it/s]
# ARI =  0.4685499120764954
# selecting DEs after first round of clustering ...
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  989
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 316.00it/s]
# finalized ARI =  0.40317387709282804
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.95it/s]
# ARI =  0.3848072769912649
# selecting DEs after first round of clustering ...
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  1
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation3/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# selecting DE num =  918
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 307.65it/s]
# finalized ARI =  0.5216239284327414

# %%
folder = "scenario3_2"
result = pd.DataFrame(columns = ["ARI", "AMI", "NMI"])
data_index  = 0
data = str(data_index + 1)
file_name = folder + "/"+ "SpaGCN/data/" + data +".h5ad"
adata = sc.read_h5ad(file_name)
adata.X = adata.X.astype("float32")
adata.obsm["spatial"] = pd.concat([adata.obs["row"], adata.obs["col"]], axis=1)
adata.obs["Ground Truth"] = adata.obs["label"]

# %%
from GAAE import GAAE, Train_ADEPT_modified, utils

utils.get_kNN(adata, rad_cutoff=1.414)
ari_ini, ARI, de_list, adata_out = Train_ADEPT_modified.train_ADEPT_use_DE(adata, n_epochs=1000, num_cluster=np.unique(adata.obs["label"]).size, device_id="1")
# Out:
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:04<00:00, 241.84it/s]
# ARI =  0.4704436095711588
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  6
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  7
# selecting DE num =  1180
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 292.71it/s]
# finalized ARI =  0.28713878149497046

# %%
adata_out
from sklearn import metrics
metrics.adjusted_rand_score(adata_out.obs['mclust_impute'], adata_out.obs['label'])
# Out:
# 0.28713878149497046

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import os
import sys
from sklearn.metrics.cluster import adjusted_rand_score
from STAGATE import STAGATE, Train_STAGATE, utils



folder_list = ["p_2000", "p_5000", "p_10000", "p_15000", "p_20000", "p_25000", "p_30000"]
for folder in folder_list:
    result = pd.DataFrame(columns = ["ARI", "AMI", "NMI"])

    for data_index in range(50):
        data = str(data_index + 1)
        file_name = "scenario2_1/" + folder + "/"+ "SpaGCN/data/" + data +".h5ad"
        adata = sc.read_h5ad(file_name)
        adata.X = adata.X.astype("float32")
        adata.obsm["spatial"] = pd.concat([adata.obs["row"], adata.obs["col"]], axis=1)


        utils.Cal_Spatial_Net(adata, rad_cutoff=1.414)
        adata = Train_STAGATE.train_STAGATE(adata)
        sc.pp.neighbors(adata, use_rep='STAGATE')
        sc.tl.umap(adata)
        adata = utils.mclust_P(adata, used_obsm='STAGATE', num_cluster=np.unique(adata.obs["label"]).size)

        from sklearn import metrics
        adata.obs["pred"] = adata.obs["mclust"]
        obs_df = adata.obs.dropna()
        ari = metrics.adjusted_rand_score(obs_df['pred'], obs_df['label'])
        nmi = metrics.normalized_mutual_info_score(obs_df['pred'], obs_df['label'])
        ami = metrics.adjusted_mutual_info_score(obs_df['pred'], obs_df['label'])

        values= [ari, ami, nmi]
        result.loc[data_index] = values

    result_file = "scenario2_1/" + folder + "/summary/" + "STAGATE.csv"
    result.to_csv(result_file )
# Out:
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 272.77it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.29it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.27it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.15it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.15it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.01it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 273.39it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.26it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.10it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.30it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.04it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.04it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 251.83it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.42it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.28it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.26it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.35it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 273.76it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.91it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.81it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:04<00:00, 248.40it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.94it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.01it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 273.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.91it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.98it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.89it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.85it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.90it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 272.85it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.27it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 272.86it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.04it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.98it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.99it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 276.00it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.68it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:04<00:00, 247.65it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.80it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.90it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.85it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.93it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 275.96it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 272.89it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.35it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.50it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.30it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.74it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.50it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.46it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.80it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.43it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.29it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.49it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.45it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.46it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.43it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.35it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.49it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.50it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.37it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.49it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.13it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.54it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.53it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.49it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.48it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.69it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.48it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.32it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.37it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.29it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.38it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.48it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.42it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.45it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.46it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.50it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.52it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.52it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.38it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 156.62it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.37it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 5000)
# 100%|██████████| 1000/1000 [00:06<00:00, 157.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.09it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.29it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.30it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.11it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.14it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.33it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.35it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.17it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.32it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.08it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.31it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.31it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.11it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.30it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.11it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.31it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.16it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.04it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.31it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.22it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.25it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.33it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.33it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.32it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.12it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.28it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.13it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.27it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.14it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.33it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.15it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 10000)
# 100%|██████████| 1000/1000 [00:11<00:00, 90.33it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.25it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.17it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.07it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.26it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.37it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.16it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.38it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.14it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.15it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.25it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.43it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.13it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.05it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.22it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.13it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.26it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.05it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.22it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 60.83it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.14it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.26it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.09it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.09it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.33it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.01it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.28it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.49it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.41it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.41it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.21it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.62it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.05it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.10it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.14it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.37it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.22it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.29it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.30it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.10it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.08it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.33it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.29it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 60.98it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.16it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 15000)
# 100%|██████████| 1000/1000 [00:16<00:00, 61.20it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.16it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.33it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.69it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.48it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.44it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.28it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.53it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.34it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.28it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.40it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.46it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.15it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.56it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.49it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.33it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.28it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.44it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.48it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.49it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.47it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.40it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.15it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.36it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.25it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.50it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.30it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.20it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.32it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.53it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.14it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.54it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.40it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 20000)
# 100%|██████████| 1000/1000 [00:20<00:00, 48.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# ...
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.55it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.52it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.47it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.54it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.55it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.60it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.59it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.54it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.54it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.58it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.55it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.51it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.59it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.50it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.58it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.49it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.56it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.57it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 25000)
# 100%|██████████| 1000/1000 [00:25<00:00, 39.49it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.17it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.21it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.24it/s]
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/sklearn/mixture/_base.py:286: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.26it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.27it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.21it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.22it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.20it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.17it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.25it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.22it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.16it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.17it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.27it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.26it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.20it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.22it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.22it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.18it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.22it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.17it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.24it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.17it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.30it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.21it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.29it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.23it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.25it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.30it/s]
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 30000)
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]

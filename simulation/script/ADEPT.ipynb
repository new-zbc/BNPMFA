# %%
import pandas as pd
import numpy as np
import scanpy as sc
import torch
import os
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
from GAAE import GAAE, Train_ADEPT_modified, utils

folder_list = ["scenario1_7", "scenario1_8", "scenario2_2", "scenario2_3", "scenario3_1", "scenario3_2"]

# %%
for folder in folder_list:
    if not os.path.exists(folder + "/" + "ADEPT"):
        os.makedirs(folder + "/" + "ADEPT")

    result = pd.DataFrame(columns = ["ARI", "AMI", "NMI"])

    for data_index in range(50):
        data = str(data_index + 1)
        file_name = folder + "/"+ "SpaGCN/data/" + data +".h5ad"
        adata = sc.read_h5ad(file_name)
        adata.X = adata.X.astype("float32")
        adata.obsm["spatial"] = pd.concat([adata.obs["row"], adata.obs["col"]], axis=1)
        adata.obs["Ground Truth"] = adata.obs["label"]
        utils.get_kNN(adata, rad_cutoff=1.414)
        ari_ini, ARI, de_list, adata_out = Train_ADEPT_modified.train_ADEPT_use_DE(adata, n_epochs=1000, num_cluster=np.unique(adata.obs["label"]).size, device_id="1")

        from sklearn import metrics
        adata.obs["pred"] = adata_out.obs['mclust_impute']
        obs_df = adata.obs.dropna()
        ari = metrics.adjusted_rand_score(obs_df['pred'], obs_df['label'])
        nmi = metrics.normalized_mutual_info_score(obs_df['pred'], obs_df['label'])
        ami = metrics.adjusted_mutual_info_score(obs_df['pred'], obs_df['label'])

        values= [ari, ami, nmi]
        result.loc[data_index] = values

        obs_df["pred"].to_csv(folder + "/ADEPT/" + data + ".csv")

    result_file = folder + "/summary/" + "ADEPT.csv"
    result.to_csv(result_file )
# Out:
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.51it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.5996059248554444
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 316.35it/s]
# finalized ARI =  0.8495885731698327
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.61it/s]
# ARI =  0.5849193876108768
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  598
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 314.95it/s]
# finalized ARI =  0.8897187218172101
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.40it/s]
# ARI =  0.6335096382261791
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 313.49it/s]
# finalized ARI =  0.8833628478473198
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.40it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.54417667227887
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 312.13it/s]
# finalized ARI =  0.8711378919584929
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.00it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6891439731263446
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 313.80it/s]
# finalized ARI =  0.8620343787878086
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 264.86it/s]
# ARI =  0.7019719017251667
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 331.78it/s]
# finalized ARI =  0.888259989099312
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:04<00:00, 249.03it/s]
# ARI =  0.5653920713785068
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 275.26it/s]
# finalized ARI =  0.9067535037807655
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.55it/s]
# ARI =  0.4907541515191247
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 314.48it/s]
# finalized ARI =  0.8257042675791756
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.40it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6343998395593353
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 314.99it/s]
# finalized ARI =  0.8528267185194287
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.52it/s]
# ARI =  0.5841048697181064
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  596
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 310.53it/s]
# finalized ARI =  0.9248974262513708
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.27it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6558725406061467
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 311.41it/s]
# finalized ARI =  0.8596826986354807
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.00it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6578323642594717
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 315.94it/s]
# finalized ARI =  0.914007087817986
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.09it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.5768863230982699
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 312.29it/s]
# finalized ARI =  0.8780521830261355
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.25it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6163550416373488
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 311.83it/s]
# finalized ARI =  0.9019195266537332
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.69it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6031843054972386
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  597
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 310.73it/s]
# finalized ARI =  0.8580690080483825
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 264.68it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6325008935593253
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  594
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 312.24it/s]
# finalized ARI =  0.8933049088097698
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.86it/s]
# ARI =  0.5973132868661646
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 316.07it/s]
# finalized ARI =  0.856324845233074
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.23it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6449116347983885
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 313.34it/s]
# finalized ARI =  0.8507951869605723
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.88it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.49072555615722313
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  597
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 315.07it/s]
# finalized ARI =  0.8708909346641707
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.17it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6670521362462755
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  598
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 314.21it/s]
# finalized ARI =  0.8874758954715154
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.47it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.5832323900905663
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 315.14it/s]
# finalized ARI =  0.8881430291084553
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.55it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6985985973610171
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  598
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 313.24it/s]
# finalized ARI =  0.8975019232322689
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.54it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6130217014437279
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  593
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 314.31it/s]
# finalized ARI =  0.9040052133104244
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.94it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.723103718410944
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 310.92it/s]
# finalized ARI =  0.9131381861753453
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.45it/s]
# ARI =  0.6483969055741078
# selecting DEs after first round of clustering ...
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 317.26it/s]
# finalized ARI =  0.868559478227725
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.53it/s]
# ARI =  0.5862425046872404
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 315.57it/s]
# finalized ARI =  0.869549854505
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.44it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6295052087851016
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  598
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 315.47it/s]
# finalized ARI =  0.9226911612445688
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.34it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.5972222158946815
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 317.86it/s]
# finalized ARI =  0.8146035784532983
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.29it/s]
# ARI =  0.5619793397896526
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 318.40it/s]
# finalized ARI =  0.8493855230881319
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.80it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.5695709201805852
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  597
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 332.47it/s]
# finalized ARI =  0.9089612928251769
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.06it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.6988170875822496
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  599
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 313.19it/s]
# finalized ARI =  0.9144279613055625
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 256.64it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.7097337354238753
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  595
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 316.64it/s]
# finalized ARI =  0.9020137346979967
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 258.57it/s]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# ARI =  0.4611911525232591
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  600
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 317.09it/s]
# finalized ARI =  0.9165694396462
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 257.16it/s]
# ARI =  0.5240137240724803
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# selecting DE num =  598
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 317.80it/s]
# finalized ARI =  0.9047286622138442
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# ...
# finalized ARI =  0.46011773253064087
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 251.62it/s]
# ARI =  0.3494584284394564
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  6
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  7
# selecting DE num =  1182
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 275.09it/s]
# finalized ARI =  0.3316021383761235
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 252.38it/s]
# ARI =  0.4262187017806304
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  6
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  7
# selecting DE num =  1210
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 276.29it/s]
# finalized ARI =  0.45832476771578134
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 251.91it/s]
# ARI =  0.3907646502612856
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  6
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  7
# selecting DE num =  1173
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 272.85it/s]
# finalized ARI =  0.3917673301411898
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 250.48it/s]
# ARI =  0.27660842317502826
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  6
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  7
# selecting DE num =  1178
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 273.12it/s]
# finalized ARI =  0.37202494294971084
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 252.41it/s]
# ARI =  0.35818336237244613
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  6
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  7
# selecting DE num =  1190
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 271.02it/s]
# finalized ARI =  0.32332772581445207
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:03<00:00, 250.23it/s]
# ARI =  0.3192014067351811
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  6
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  7
# selecting DE num =  1196
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 275.68it/s]
# finalized ARI =  0.2694986518832822

# %%
folder = "scenario3_2"
result = pd.DataFrame(columns = ["ARI", "AMI", "NMI"])
data_index  = 0
data = str(data_index + 1)
file_name = folder + "/"+ "SpaGCN/data/" + data +".h5ad"
adata = sc.read_h5ad(file_name)
adata.X = adata.X.astype("float32")
adata.obsm["spatial"] = pd.concat([adata.obs["row"], adata.obs["col"]], axis=1)
adata.obs["Ground Truth"] = adata.obs["label"]

# %%
from GAAE import GAAE, Train_ADEPT_modified, utils

utils.get_kNN(adata, rad_cutoff=1.414)
ari_ini, ARI, de_list, adata_out = Train_ADEPT_modified.train_ADEPT_use_DE(adata, n_epochs=1000, num_cluster=np.unique(adata.obs["label"]).size, device_id="1")
# Out:
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/project07/.conda/envs/SpatialGlue/lib/python3.8/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# ------Calculating spatial graph...
# The graph contains 6240 edges, 1600 cells.
# 3.9000 neighbors per cell on average.
# Size of Input:  (1600, 2000)
# 100%|██████████| 1000/1000 [00:04<00:00, 241.84it/s]
# ARI =  0.4704436095711588
# selecting DEs after first round of clustering ...
# label =  1
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  2
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  3
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  4
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  5
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  6
# /disk18T3/Bencong/project06/simulation1/GAAE/Train_ADEPT_modified.py:292: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   gene_list = adata.var.index[:, np.newaxis]
# label =  7
# selecting DE num =  1180
# train a new AE with the potential DEs ...
# DE expression matrix non-zero rate =  1.0
# 100%|██████████| 1000/1000 [00:03<00:00, 292.71it/s]
# finalized ARI =  0.28713878149497046

# %%
adata_out
from sklearn import metrics
metrics.adjusted_rand_score(adata_out.obs['mclust_impute'], adata_out.obs['label'])
# Out:
# 0.28713878149497046
